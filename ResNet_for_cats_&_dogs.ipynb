# %% [markdown]
# <a href="https://colab.research.google.com/github/Remon19/journey-into-ML/blob/main/ResNet_for_cats_%26_dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import glob
import numpy as np
import os
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
import torchvision.models as models
import torch.cuda as cuda
import time
from torch.autograd import Variable

# %%
# !git clone https://github.com/ardamavi/Dog-Cat-Classifier.git
# Out:
# Cloning into 'Dog-Cat-Classifier'...
# remote: Enumerating objects: 1654, done.
# remote: Total 1654 (delta 0), reused 0 (delta 0), pack-reused 1654
# Receiving objects: 100% (1654/1654), 34.83 MiB | 43.55 MiB/s, done.
# Resolving deltas: 100% (147/147), done.

# %%
class NeuralNet(nn.Module):
  def __init__(self,input_size, n_nodes, output_size) -> None:
      super(NeuralNet, self).__init__()
      self.layer1 = nn.Linear(input_size, n_nodes)
      self.output_layer = nn.Linear(n_nodes, output_size)

  def forward(self, x):
    x = self.layer1(x)
    x = F.relu(x)
    x = self.output_layer(x)
    x = F.sigmoid(x)
    return x

# %%
path = '/content/Dog-Cat-Classifier/Data/Train_Data/'
dog_files = [f for f in glob.glob(path +'dog/*.jpg')]
cat_files = [f for f in glob.glob(path + 'cat/*.jpg')]
files = dog_files + cat_files
print(f'Total no of images {len(files)}')
no_of_images = len(files)
# Out:
# Total no of images 1399

# %%
shuffle = np.random.permutation(no_of_images)

# %%
os.mkdir(os.path.join(path,'train'))
os.mkdir(os.path.join(path,'valid'))
for t in ['train','valid']:
  for folder in ['dog/','cat/']:
    os.mkdir(os.path.join(path,t,folder))

# %%
for i in shuffle[:250]:
  folder = files[i].split('/')[-2].split('.')[0]
  image = files[i].split('/')[-1]
  os.rename(files[i],os.path.join(path,'valid',folder,image))

# %%
for i in shuffle[250:]:
  folder = files[i].split('/')[-2].split('.')[0]
  image = files[i].split('/')[-1]
  os.rename(files[i],os.path.join(path,'train',folder,image))

# %%
transform = transforms.Compose([transforms.Resize((224,224))
                              ,transforms.ToTensor()
                              ,transforms.Normalize([0.12, 0.11,
0.40], [0.89, 0.21, 0.12])])
train = ImageFolder(os.path.join(path,'train/'),transform)
valid = ImageFolder(os.path.join(path,'valid/'),transform)

# %%
train_data_generator = torch.utils.data.DataLoader(train,shuffle=True,batch_size=64,num_workers=8)
valid_data_generator = torch.utils.data.DataLoader(valid,batch_size=64,num_workers=8)
dataset_sizes = {'train': len(train), 'valid': len(valid)}
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
pretrained_resnet = models.resnet18(pretrained=True)
number_features = pretrained_resnet.fc.in_features
pretrained_resnet.fc = nn.Linear(number_features, 4)
if cuda.is_available:
  pretrained_resnet = pretrained_resnet.cuda()

# %%
learning_rate = 0.005
criterion = nn.CrossEntropyLoss()
fit_optimizer = torch.optim.SGD(pretrained_resnet.parameters(), lr=0.005,
momentum=0.6)
exp_learning_rate_scheduler = torch.optim.lr_scheduler.StepLR(fit_optimizer,
step_size=2, gamma=0.05)
dataloaders = {'train': train_data_generator, 'valid' : valid_data_generator }

# %%
def train_my_model(model, dataloaders,criterion, optimizer, scheduler,number_epochs=20):
  since = time.time()
  best_model_weights = model.state_dict()
  best_accuracy = 0.0
  for epoch in range(number_epochs):
    print('Epoch {}/{}'.format(epoch, number_epochs - 1))
    print('-' * 10)
    for each_phase in ['train', 'valid']:
      if each_phase == 'train':
        scheduler.step()
        model.train(True)
      else:
        model.train(False)
      running_loss = 0.0
      running_corrects = 0
      for data in dataloaders[each_phase]:
        input_data, label_data = data
        if cuda.is_available():
          input_data = Variable(input_data.cuda())
          label_data = Variable(label_data.cuda())
        else:
          input_data, label_data = Variable(input_data), Variable(label_data)
        optimizer.zero_grad()
        outputs = model(input_data)
        _, preds = torch.max(outputs.data, 1)
        loss = criterion(outputs, label_data)
        if each_phase == 'train':
          loss.backward()
          optimizer.step()
        running_loss += loss.data
        running_corrects += torch.sum(preds == label_data.data)
        epoch_loss = running_loss / dataset_sizes[each_phase]
        epoch_acc = running_corrects / dataset_sizes[each_phase]
        print('{} Loss: {:.4f} Acc: {:.4f}'.format(each_phase,
        epoch_loss, epoch_acc))
        if each_phase == 'valid' and epoch_acc > best_accuracy:
          best_accuracy = epoch_acc
          best_model_weights = model.state_dict()
  print()
  time_elapsed = time.time() - since
  print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60,
  time_elapsed % 60))
  print('Best val Acc: {:4f}'.format(best_accuracy))
  model.load_state_dict(best_model_weights)
  return model

# %%
train_my_model(pretrained_resnet,dataloaders, criterion, fit_optimizer,
exp_learning_rate_scheduler, number_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.0013 Acc: 0.0070
# train Loss: 0.0021 Acc: 0.0453
# train Loss: 0.0027 Acc: 0.0870
# train Loss: 0.0032 Acc: 0.1323
# train Loss: 0.0036 Acc: 0.1828
# train Loss: 0.0040 Acc: 0.2289
# train Loss: 0.0043 Acc: 0.2794
# train Loss: 0.0045 Acc: 0.3307
# train Loss: 0.0048 Acc: 0.3795
# train Loss: 0.0050 Acc: 0.4308
# train Loss: 0.0052 Acc: 0.4813
# train Loss: 0.0054 Acc: 0.5335
# train Loss: 0.0056 Acc: 0.5857
# train Loss: 0.0058 Acc: 0.6388
# train Loss: 0.0059 Acc: 0.6919
# train Loss: 0.0061 Acc: 0.7467
# train Loss: 0.0062 Acc: 0.8016
# train Loss: 0.0063 Acc: 0.8538
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0014 Acc: 0.4840
# valid Loss: 0.0020 Acc: 0.7200
# valid Loss: 0.0025 Acc: 0.9480
# Epoch 1/19
# ----------
# train Loss: 0.0001 Acc: 0.0540
# train Loss: 0.0003 Acc: 0.1062
# train Loss: 0.0004 Acc: 0.1601
# train Loss: 0.0005 Acc: 0.2150
# train Loss: 0.0006 Acc: 0.2698
# train Loss: 0.0008 Acc: 0.3255
# train Loss: 0.0009 Acc: 0.3803
# train Loss: 0.0010 Acc: 0.4360
# train Loss: 0.0010 Acc: 0.4917
# train Loss: 0.0012 Acc: 0.5448
# train Loss: 0.0013 Acc: 0.5997
# train Loss: 0.0014 Acc: 0.6519
# train Loss: 0.0015 Acc: 0.7067
# train Loss: 0.0017 Acc: 0.7563
# train Loss: 0.0018 Acc: 0.8094
# train Loss: 0.0020 Acc: 0.8634
# train Loss: 0.0021 Acc: 0.9182
# train Loss: 0.0022 Acc: 0.9695
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4840
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 2/19
# ----------
# train Loss: 0.0001 Acc: 0.0548
# train Loss: 0.0002 Acc: 0.1088
# train Loss: 0.0004 Acc: 0.1610
# train Loss: 0.0005 Acc: 0.2150
# train Loss: 0.0006 Acc: 0.2698
# train Loss: 0.0007 Acc: 0.3255
# train Loss: 0.0009 Acc: 0.3795
# train Loss: 0.0010 Acc: 0.4352
# train Loss: 0.0011 Acc: 0.4900
# train Loss: 0.0012 Acc: 0.5448
# train Loss: 0.0013 Acc: 0.5988
# train Loss: 0.0014 Acc: 0.6545
# train Loss: 0.0015 Acc: 0.7093
# train Loss: 0.0016 Acc: 0.7641
# train Loss: 0.0017 Acc: 0.8198
# train Loss: 0.0018 Acc: 0.8738
# train Loss: 0.0019 Acc: 0.9278
# train Loss: 0.0021 Acc: 0.9800
# valid Loss: 0.0008 Acc: 0.2440
# valid Loss: 0.0014 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7160
# valid Loss: 0.0026 Acc: 0.9440
# Epoch 3/19
# ----------
# train Loss: 0.0001 Acc: 0.0557
# train Loss: 0.0002 Acc: 0.1097
# train Loss: 0.0003 Acc: 0.1645
# train Loss: 0.0004 Acc: 0.2202
# train Loss: 0.0005 Acc: 0.2759
# train Loss: 0.0006 Acc: 0.3307
# train Loss: 0.0007 Acc: 0.3864
# train Loss: 0.0009 Acc: 0.4404
# train Loss: 0.0010 Acc: 0.4943
# train Loss: 0.0010 Acc: 0.5500
# train Loss: 0.0011 Acc: 0.6049
# train Loss: 0.0013 Acc: 0.6588
# train Loss: 0.0014 Acc: 0.7102
# train Loss: 0.0015 Acc: 0.7659
# train Loss: 0.0017 Acc: 0.8181
# train Loss: 0.0018 Acc: 0.8712
# train Loss: 0.0019 Acc: 0.9252
# train Loss: 0.0020 Acc: 0.9782
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0026 Acc: 0.9400
# Epoch 4/19
# ----------
# train Loss: 0.0001 Acc: 0.0548
# train Loss: 0.0002 Acc: 0.1097
# train Loss: 0.0003 Acc: 0.1645
# train Loss: 0.0004 Acc: 0.2185
# train Loss: 0.0006 Acc: 0.2724
# train Loss: 0.0007 Acc: 0.3281
# train Loss: 0.0008 Acc: 0.3803
# train Loss: 0.0009 Acc: 0.4343
# train Loss: 0.0010 Acc: 0.4883
# train Loss: 0.0011 Acc: 0.5440
# train Loss: 0.0012 Acc: 0.5979
# train Loss: 0.0013 Acc: 0.6536
# train Loss: 0.0014 Acc: 0.7093
# train Loss: 0.0015 Acc: 0.7641
# train Loss: 0.0016 Acc: 0.8198
# train Loss: 0.0017 Acc: 0.8738
# train Loss: 0.0018 Acc: 0.9295
# train Loss: 0.0019 Acc: 0.9817
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0014 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 5/19
# ----------
# train Loss: 0.0001 Acc: 0.0540
# train Loss: 0.0002 Acc: 0.1097
# train Loss: 0.0003 Acc: 0.1645
# train Loss: 0.0004 Acc: 0.2176
# train Loss: 0.0005 Acc: 0.2707
# train Loss: 0.0007 Acc: 0.3220
# train Loss: 0.0008 Acc: 0.3768
# train Loss: 0.0010 Acc: 0.4308
# train Loss: 0.0011 Acc: 0.4856
# train Loss: 0.0011 Acc: 0.5413
# train Loss: 0.0012 Acc: 0.5970
# train Loss: 0.0013 Acc: 0.6527
# train Loss: 0.0014 Acc: 0.7084
# train Loss: 0.0016 Acc: 0.7633
# train Loss: 0.0017 Acc: 0.8172
# train Loss: 0.0018 Acc: 0.8703
# train Loss: 0.0019 Acc: 0.9252
# train Loss: 0.0020 Acc: 0.9774
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 6/19
# ----------
# train Loss: 0.0001 Acc: 0.0548
# train Loss: 0.0002 Acc: 0.1097
# train Loss: 0.0003 Acc: 0.1628
# train Loss: 0.0004 Acc: 0.2176
# train Loss: 0.0005 Acc: 0.2724
# train Loss: 0.0006 Acc: 0.3272
# train Loss: 0.0008 Acc: 0.3803
# train Loss: 0.0009 Acc: 0.4360
# train Loss: 0.0009 Acc: 0.4909
# train Loss: 0.0011 Acc: 0.5448
# train Loss: 0.0012 Acc: 0.6005
# train Loss: 0.0013 Acc: 0.6545
# train Loss: 0.0014 Acc: 0.7084
# train Loss: 0.0016 Acc: 0.7598
# train Loss: 0.0017 Acc: 0.8155
# train Loss: 0.0018 Acc: 0.8712
# train Loss: 0.0019 Acc: 0.9252
# train Loss: 0.0020 Acc: 0.9774
# valid Loss: 0.0006 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4840
# valid Loss: 0.0021 Acc: 0.7160
# valid Loss: 0.0027 Acc: 0.9440
# Epoch 7/19
# ----------
# train Loss: 0.0001 Acc: 0.0531
# train Loss: 0.0002 Acc: 0.1070
# train Loss: 0.0004 Acc: 0.1601
# train Loss: 0.0005 Acc: 0.2115
# train Loss: 0.0006 Acc: 0.2663
# train Loss: 0.0007 Acc: 0.3203
# train Loss: 0.0008 Acc: 0.3734
# train Loss: 0.0009 Acc: 0.4291
# train Loss: 0.0010 Acc: 0.4848
# train Loss: 0.0011 Acc: 0.5387
# train Loss: 0.0013 Acc: 0.5927
# train Loss: 0.0013 Acc: 0.6484
# train Loss: 0.0015 Acc: 0.7032
# train Loss: 0.0016 Acc: 0.7581
# train Loss: 0.0017 Acc: 0.8129
# train Loss: 0.0017 Acc: 0.8686
# train Loss: 0.0019 Acc: 0.9225
# train Loss: 0.0020 Acc: 0.9730
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 8/19
# ----------
# train Loss: 0.0001 Acc: 0.0531
# train Loss: 0.0002 Acc: 0.1070
# train Loss: 0.0004 Acc: 0.1601
# train Loss: 0.0005 Acc: 0.2158
# train Loss: 0.0006 Acc: 0.2715
# train Loss: 0.0007 Acc: 0.3264
# train Loss: 0.0008 Acc: 0.3821
# train Loss: 0.0009 Acc: 0.4352
# train Loss: 0.0010 Acc: 0.4900
# train Loss: 0.0011 Acc: 0.5440
# train Loss: 0.0012 Acc: 0.5988
# train Loss: 0.0013 Acc: 0.6545
# train Loss: 0.0014 Acc: 0.7102
# train Loss: 0.0015 Acc: 0.7650
# train Loss: 0.0016 Acc: 0.8181
# train Loss: 0.0018 Acc: 0.8721
# train Loss: 0.0019 Acc: 0.9260
# train Loss: 0.0020 Acc: 0.9791
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0014 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 9/19
# ----------
# train Loss: 0.0001 Acc: 0.0557
# train Loss: 0.0002 Acc: 0.1088
# train Loss: 0.0003 Acc: 0.1645
# train Loss: 0.0004 Acc: 0.2176
# train Loss: 0.0006 Acc: 0.2715
# train Loss: 0.0006 Acc: 0.3264
# train Loss: 0.0008 Acc: 0.3812
# train Loss: 0.0009 Acc: 0.4352
# train Loss: 0.0010 Acc: 0.4891
# train Loss: 0.0011 Acc: 0.5448
# train Loss: 0.0012 Acc: 0.5997
# train Loss: 0.0014 Acc: 0.6501
# train Loss: 0.0015 Acc: 0.7041
# train Loss: 0.0016 Acc: 0.7598
# train Loss: 0.0017 Acc: 0.8146
# train Loss: 0.0018 Acc: 0.8695
# train Loss: 0.0019 Acc: 0.9243
# train Loss: 0.0020 Acc: 0.9765
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 10/19
# ----------
# train Loss: 0.0001 Acc: 0.0557
# train Loss: 0.0002 Acc: 0.1097
# train Loss: 0.0004 Acc: 0.1628
# train Loss: 0.0004 Acc: 0.2176
# train Loss: 0.0005 Acc: 0.2724
# train Loss: 0.0007 Acc: 0.3281
# train Loss: 0.0008 Acc: 0.3838
# train Loss: 0.0009 Acc: 0.4386
# train Loss: 0.0010 Acc: 0.4909
# train Loss: 0.0011 Acc: 0.5457
# train Loss: 0.0012 Acc: 0.6005
# train Loss: 0.0013 Acc: 0.6562
# train Loss: 0.0014 Acc: 0.7119
# train Loss: 0.0015 Acc: 0.7650
# train Loss: 0.0016 Acc: 0.8207
# train Loss: 0.0017 Acc: 0.8755
# train Loss: 0.0018 Acc: 0.9278
# train Loss: 0.0019 Acc: 0.9800
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 11/19
# ----------
# train Loss: 0.0001 Acc: 0.0531
# train Loss: 0.0003 Acc: 0.1062
# train Loss: 0.0004 Acc: 0.1619
# train Loss: 0.0005 Acc: 0.2158
# train Loss: 0.0006 Acc: 0.2715
# train Loss: 0.0007 Acc: 0.3255
# train Loss: 0.0008 Acc: 0.3795
# train Loss: 0.0009 Acc: 0.4343
# train Loss: 0.0010 Acc: 0.4883
# train Loss: 0.0011 Acc: 0.5431
# train Loss: 0.0013 Acc: 0.5970
# train Loss: 0.0014 Acc: 0.6519
# train Loss: 0.0014 Acc: 0.7067
# train Loss: 0.0015 Acc: 0.7615
# train Loss: 0.0016 Acc: 0.8164
# train Loss: 0.0017 Acc: 0.8712
# train Loss: 0.0018 Acc: 0.9260
# train Loss: 0.0019 Acc: 0.9774
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 12/19
# ----------
# train Loss: 0.0001 Acc: 0.0540
# train Loss: 0.0002 Acc: 0.1097
# train Loss: 0.0003 Acc: 0.1628
# train Loss: 0.0004 Acc: 0.2167
# train Loss: 0.0005 Acc: 0.2715
# train Loss: 0.0006 Acc: 0.3272
# train Loss: 0.0007 Acc: 0.3829
# train Loss: 0.0009 Acc: 0.4369
# train Loss: 0.0010 Acc: 0.4909
# train Loss: 0.0011 Acc: 0.5457
# train Loss: 0.0012 Acc: 0.5988
# train Loss: 0.0013 Acc: 0.6536
# train Loss: 0.0014 Acc: 0.7076
# train Loss: 0.0015 Acc: 0.7633
# train Loss: 0.0017 Acc: 0.8172
# train Loss: 0.0018 Acc: 0.8721
# train Loss: 0.0019 Acc: 0.9278
# train Loss: 0.0020 Acc: 0.9800
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 13/19
# ----------
# train Loss: 0.0001 Acc: 0.0548
# train Loss: 0.0002 Acc: 0.1105
# train Loss: 0.0003 Acc: 0.1636
# train Loss: 0.0004 Acc: 0.2176
# train Loss: 0.0006 Acc: 0.2715
# train Loss: 0.0007 Acc: 0.3255
# train Loss: 0.0008 Acc: 0.3795
# train Loss: 0.0009 Acc: 0.4326
# train Loss: 0.0010 Acc: 0.4883
# train Loss: 0.0011 Acc: 0.5440
# train Loss: 0.0012 Acc: 0.5979
# train Loss: 0.0013 Acc: 0.6536
# train Loss: 0.0014 Acc: 0.7093
# train Loss: 0.0015 Acc: 0.7650
# train Loss: 0.0016 Acc: 0.8198
# train Loss: 0.0017 Acc: 0.8747
# train Loss: 0.0018 Acc: 0.9286
# train Loss: 0.0019 Acc: 0.9809
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4840
# valid Loss: 0.0021 Acc: 0.7160
# valid Loss: 0.0027 Acc: 0.9440
# Epoch 14/19
# ----------
# train Loss: 0.0001 Acc: 0.0548
# train Loss: 0.0002 Acc: 0.1079
# train Loss: 0.0004 Acc: 0.1601
# train Loss: 0.0005 Acc: 0.2141
# train Loss: 0.0006 Acc: 0.2698
# train Loss: 0.0007 Acc: 0.3246
# train Loss: 0.0008 Acc: 0.3795
# train Loss: 0.0009 Acc: 0.4326
# train Loss: 0.0010 Acc: 0.4883
# train Loss: 0.0011 Acc: 0.5440
# train Loss: 0.0012 Acc: 0.5988
# train Loss: 0.0013 Acc: 0.6545
# train Loss: 0.0014 Acc: 0.7102
# train Loss: 0.0015 Acc: 0.7659
# train Loss: 0.0016 Acc: 0.8216
# train Loss: 0.0017 Acc: 0.8755
# train Loss: 0.0018 Acc: 0.9304
# train Loss: 0.0019 Acc: 0.9826
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 15/19
# ----------
# train Loss: 0.0001 Acc: 0.0548
# train Loss: 0.0002 Acc: 0.1088
# train Loss: 0.0004 Acc: 0.1636
# train Loss: 0.0005 Acc: 0.2185
# train Loss: 0.0006 Acc: 0.2724
# train Loss: 0.0007 Acc: 0.3281
# train Loss: 0.0008 Acc: 0.3821
# train Loss: 0.0009 Acc: 0.4360
# train Loss: 0.0010 Acc: 0.4909
# train Loss: 0.0011 Acc: 0.5448
# train Loss: 0.0012 Acc: 0.5979
# train Loss: 0.0013 Acc: 0.6527
# train Loss: 0.0014 Acc: 0.7058
# train Loss: 0.0015 Acc: 0.7607
# train Loss: 0.0016 Acc: 0.8164
# train Loss: 0.0017 Acc: 0.8721
# train Loss: 0.0018 Acc: 0.9269
# train Loss: 0.0020 Acc: 0.9791
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 16/19
# ----------
# train Loss: 0.0001 Acc: 0.0548
# train Loss: 0.0002 Acc: 0.1105
# train Loss: 0.0003 Acc: 0.1645
# train Loss: 0.0005 Acc: 0.2185
# train Loss: 0.0006 Acc: 0.2724
# train Loss: 0.0007 Acc: 0.3272
# train Loss: 0.0008 Acc: 0.3803
# train Loss: 0.0009 Acc: 0.4352
# train Loss: 0.0010 Acc: 0.4909
# train Loss: 0.0011 Acc: 0.5466
# train Loss: 0.0012 Acc: 0.6014
# train Loss: 0.0013 Acc: 0.6562
# train Loss: 0.0014 Acc: 0.7111
# train Loss: 0.0015 Acc: 0.7641
# train Loss: 0.0016 Acc: 0.8198
# train Loss: 0.0018 Acc: 0.8747
# train Loss: 0.0019 Acc: 0.9304
# train Loss: 0.0020 Acc: 0.9817
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 17/19
# ----------
# train Loss: 0.0001 Acc: 0.0548
# train Loss: 0.0002 Acc: 0.1105
# train Loss: 0.0003 Acc: 0.1654
# train Loss: 0.0004 Acc: 0.2202
# train Loss: 0.0005 Acc: 0.2750
# train Loss: 0.0006 Acc: 0.3307
# train Loss: 0.0007 Acc: 0.3856
# train Loss: 0.0008 Acc: 0.4413
# train Loss: 0.0009 Acc: 0.4952
# train Loss: 0.0010 Acc: 0.5492
# train Loss: 0.0011 Acc: 0.6049
# train Loss: 0.0012 Acc: 0.6597
# train Loss: 0.0013 Acc: 0.7154
# train Loss: 0.0014 Acc: 0.7694
# train Loss: 0.0016 Acc: 0.8225
# train Loss: 0.0017 Acc: 0.8773
# train Loss: 0.0018 Acc: 0.9330
# train Loss: 0.0019 Acc: 0.9809
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0013 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 18/19
# ----------
# train Loss: 0.0001 Acc: 0.0531
# train Loss: 0.0002 Acc: 0.1079
# train Loss: 0.0003 Acc: 0.1628
# train Loss: 0.0005 Acc: 0.2158
# train Loss: 0.0006 Acc: 0.2707
# train Loss: 0.0007 Acc: 0.3246
# train Loss: 0.0008 Acc: 0.3803
# train Loss: 0.0009 Acc: 0.4352
# train Loss: 0.0010 Acc: 0.4891
# train Loss: 0.0011 Acc: 0.5448
# train Loss: 0.0012 Acc: 0.6005
# train Loss: 0.0013 Acc: 0.6536
# train Loss: 0.0014 Acc: 0.7084
# train Loss: 0.0015 Acc: 0.7624
# train Loss: 0.0016 Acc: 0.8164
# train Loss: 0.0018 Acc: 0.8712
# train Loss: 0.0019 Acc: 0.9260
# train Loss: 0.0019 Acc: 0.9791
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0014 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0027 Acc: 0.9400
# Epoch 19/19
# ----------
# train Loss: 0.0001 Acc: 0.0548
# train Loss: 0.0002 Acc: 0.1088
# train Loss: 0.0003 Acc: 0.1628
# train Loss: 0.0004 Acc: 0.2158
# train Loss: 0.0006 Acc: 0.2707
# train Loss: 0.0006 Acc: 0.3264
# train Loss: 0.0007 Acc: 0.3821
# train Loss: 0.0008 Acc: 0.4369
# train Loss: 0.0010 Acc: 0.4874
# train Loss: 0.0011 Acc: 0.5431
# train Loss: 0.0012 Acc: 0.5988
# train Loss: 0.0013 Acc: 0.6536
# train Loss: 0.0014 Acc: 0.7076
# train Loss: 0.0015 Acc: 0.7581
# train Loss: 0.0017 Acc: 0.8120
# train Loss: 0.0017 Acc: 0.8668
# train Loss: 0.0018 Acc: 0.9225
# train Loss: 0.0020 Acc: 0.9730
# valid Loss: 0.0007 Acc: 0.2440
# valid Loss: 0.0014 Acc: 0.4800
# valid Loss: 0.0021 Acc: 0.7120
# valid Loss: 0.0026 Acc: 0.9400
#
# Training complete in 3m 1s
# Best val Acc: 0.948000
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=4, bias=True)
# )
